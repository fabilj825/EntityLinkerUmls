# %%
# !pip install transformers[torch]
# !pip install scispacy
# !pip install seqeval
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 6.8 MB/s eta 0:00:00
# ...
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# ...
#   Created wheel for nmslib: filename=nmslib-2.1.1-cp310-cp310-linux_x86_64.whl size=13578644 sha256=726f89b115697a14963005acc28a99ddd0e5ea1748ad5a63fd5b80f10581131c
#   Stored in directory: /root/.cache/pip/wheels/21/1a/5d/4cc754a5b1a88405cad184b76f823897a63a8d19afcd4b9314
# Successfully built nmslib
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# ...

# %%
from scispacy.data_util import read_full_med_mentions
from typing import Optional, Callable, Iterable, Iterator
from pathlib import Path

import random
import itertools
import spacy
import warnings
from spacy.training import Corpus, Example
from spacy.language import Language

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/biobert/named-entity-recognition')

# %%
# !export SAVE_DIR=./output
# !export DATA_DIR=../datasets/NER

# !export MAX_LENGTH=192
# !export BATCH_SIZE=32
# !export NUM_EPOCHS=6
# !export SAVE_STEPS=5000
# !export ENTITY=all
# !export SEED=1

# %%
# !python run_ner.py \
     --data_dir ./datasets/NER/all \
     --labels ./datasets/NER/all/labels.txt \
     --model_name_or_path dmis-lab/biobert-base-cased-v1.1 \
     --output_dir ./output/all \
     --max_seq_length 192 \
     --num_train_epochs 6 \
     --per_device_train_batch_size 32 \
     --save_steps 5000 \
     --seed 1 \
     --do_train \
     --do_eval \
     --overwrite_output_dir
# Out:
# 2024-01-29 13:06:58.624441: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-29 13:06:58.624487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-29 13:06:58.625720: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-29 13:06:59.741085: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 01/29/2024 13:07:00 - WARNING - __main__ -   Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: True, 16-bits training: False
# ...
